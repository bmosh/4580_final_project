# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import time
import random

import worker as wr
import simulation as sm

import os

# %% [markdown]
# # Simulation Project Demo (FA23)
#
# The purpose of this notebook is to further modularize simulation model v1 and incorporate our own twists to examine the behavior of gender-based bias in the corporate workplace.

# %%
# Global Variables / References:

# Appropriate staff sizes for each level:
level_sizes = {
    1 : 700,
    2 : 200,
    3 : 75,
    4 : 25
}

# The impact that seniority has on staying time - older people retire later?
# Set negative for opposite effect.
level_ext_stay_times = {
    1 : 1,
    2 : 4,
    3 : 6,
    4 : 10
}

# The impact that gender has on staying time -- women pushed out quicker?
gender_stay_times = {
    0 : 5,
    1 : 3
}

# A database to store workers, organized by level:
# Implemented as simple lists, ordered from most to least senior by employee index.
worker_db = {
    1 : [],
    2 : [],
    3 : [],
    4 : []
}

# %% [markdown]
# ### Base Hiring/Promoting/Leaving Processes

# %%
def base_remove_expired_workers(worker_db):
    """
    This function traverses through the database of workers, and removes
    those with end times that have been reached. It does so by iterating through
    each level of worker in the database, checking the current time vs. the
    worker's end time. If this time has passed, then we remove the worker.
    """
    for level in worker_db.keys():
        
        l = len(worker_db[level])
        idx = 0
        
#       keys are being changed during the loop- for loop won't work!
        while idx < l:
#           if a worker has 'expired', kick 'em out!
            if worker_db[level][idx].get_end_time() < time.time():
                worker_db[level] = worker_db[level][:idx] \
                                    + worker_db[level][idx+1:]
#               reflect that the size of the level is one less after removal
                l -= 1
            idx += 1
            
    
def base_check_leave(worker_db, leave_db):
    for level in worker_db.keys():
        l = len(worker_db[level])
        idx = 0
        
        while idx < l:
            if worker_db[level][idx].det_go_on_leave():
                leave_db[level].append(worker_db[level][idx])
                worker_db[level] = worker_db[level][:idx] \
                                        + worker_db[level][idx+1:]
                l -= 1
            idx += 1
     
    for level in leave_db.keys():
        l = len(leave_db[level])
        idx = 0
        
        while idx < l:
            if time.time() > leave_db[level][idx].get_leave_time():
                worker_db[level].append(leave_db[level][idx])
                worker_db[level][len(worker_db[level]) - 1].set_end_time(gender_stay_times, level_ext_stay_times)
                leave_db[level] = leave_db[level][:idx] + leave_db[level][idx+1:]
                l -= 1
            idx += 1      

def base_hire_worker(worker_db, level, idx, male_productivity=(5,2), female_productivity=(5,2),\
                     all_male=False, all_female=False):
    """
    This function hires new workers
    """
    
    assert not all_female or not all_male
    # Randomized gender for new hire -- Change to 3 evenutally for NB case?
    if all_female:
        gender = 1
    elif all_male:
        gender = 0
    else:
        gender = random.randint(0,1)

    # Create worker:
    hire = wr.Worker(level, gender, idx, time.time())
    hire.set_end_time(gender_stay_times, level_ext_stay_times)
    hire.set_productivity(male_productivity, female_productivity)
    

    # Add worker to worker database:     
    worker_db[hire.get_level()].append(hire)
    
    
def base_promote_workers(worker_db, leave_db, alpha, gamma, n):
    # Promote to fill ranks:           
    level = max(worker_db.keys())
#     print(level)
#   Promote employees to fill levels 2-4. Work from top to ensure each level is full.
    while level > 1:
        while len(worker_db[level]) + len(leave_db) < level_sizes[level]:
#           promote most senior employee from one level down:
            worker_db[level].append(worker_db[level-1][0])
    
#           adjust level, end time for promoted employee
            worker_db[level][len(worker_db[level]) - 1].promote(gender_stay_times, level_ext_stay_times)
            worker_db[level][len(worker_db[level]) - 1].set_end_time(gender_stay_times, level_ext_stay_times)
        
#           remove employee from level below
            worker_db[level-1] = worker_db[level-1][1:]
        level -= 1

# %% [markdown]
# ### Alternative Hiring/Promoting/Leaving Processes

# %%
def logit_promote_workers(worker_db, leave_db, alpha, gamma, n=5):
    level = max(worker_db.keys())
    
    while level > 1:
        while len(worker_db[level]) + len(leave_db) < level_sizes[level]:
            worker_pool = worker_db[level-1][:n]
            
            probabilities = [math.e**((gamma*worker.get_time_on_level() \
                                      + alpha*int(worker.is_male()))/35) \
                                         for worker in worker_pool]
            
            ps = [p / sum(probabilities) for p in probabilities]
            
            cumul_probabilities = [sum(ps[:i+1]) for i in range(len(ps))]
            
            u = np.random.uniform()
            
            for i in range(len(cumul_probabilities)):
                if cumul_probabilities[i] >= u:
                    selection = i
                    break
                    
            
            worker_db[level].append(worker_db[level-1][selection])
            
            worker_db[level][len(worker_db[level]) - 1].promote(gender_stay_times, level_ext_stay_times)
            
            worker_db[level-1] = worker_db[level-1][:selection] \
                                    + worker_db[level-1][selection+1:]
        level -= 1
        
            
def prod_promote_workers(worker_db, leave_db, alpha, gamma, n=5):
    """
    Promote workers based off their productivity. 
    
    Modeled mathematically as INSERT MODEL HERE
    
    Inputs: 
    - worker_db: the database of workers
    - n: number of workers selected to promote from
    - alpha, gamma: currently unused sensitivity tuning params
    
    Outputs:
    - None
    """
    # @TODO
    level = max(worker_db.keys())
    
    while level > 1:
        while len(worker_db[level]) + len(leave_db) < level_sizes[level]:
            
            worker_pool = worker_db[level-1][:n]
            
            probabilities = [math.e**((worker.get_productivity()) / 10) \
                                         for worker in worker_pool]
                    
            ps = [p / sum(probabilities) for p in probabilities]
            
             
#             for i in range(n):
#                 if worker_pool[i].is_male():
#                     print("male: ", ps[i], worker_pool[i].get_productivity())
#                 else:
#                     print("female: ", ps[i], worker_pool[i].get_productivity())
            
            cumul_probabilities = [sum(ps[:i+1]) for i in range(len(ps))]
            
            u = np.random.uniform()
            
            for i in range(len(cumul_probabilities)):
                if cumul_probabilities[i] >= u:
                    selection = i
                    break
                    
            
            worker_db[level].append(worker_db[level-1][selection])
            
            worker_db[level][len(worker_db[level]) - 1].promote(gender_stay_times, level_ext_stay_times)
            
            worker_db[level-1] = worker_db[level-1][:selection] \
                                    + worker_db[level-1][selection+1:]
        level -= 1

# %% [markdown]
# ## Testing / Playground:

# %%
def make_timestamp():
    t = time.time()
    t = str(t).split(".")[1]
    t = t[0:len(t)-2]
    return t

# %% [markdown]
# ## Simulations:
#
# To run a simulation, call an object and pass in the worker database, level sizes, hiring/promoting/leaving processes, and round length.

# %%
n=10
round_length = 1
num_rounds = 40

parental_leave = False

# Alpha / Gamma Values - Used in Logit/Prod Analysis
alpha = 0
gamma = 1

male_productivity = (6,2)
female_productivity = (6,2)

sim_type = "prod"

path = os.path.join(os.getcwd(), "simulation_data")

# %%
sim_types = {
    
    "base" : (base_remove_expired_workers, \
              base_hire_worker, base_promote_workers),
    
    "logit" : (base_remove_expired_workers, \
              base_hire_worker, logit_promote_workers),
    
    "prod" : (base_remove_expired_workers, \
              base_hire_worker, prod_promote_workers, \
             male_productivity, female_productivity)
}

# %%
basic_sim = sm.Simulation(sim_type, level_sizes, \
                          sim_types[sim_type][0],sim_types[sim_type][1],sim_types[sim_type][2], \
                          alpha, gamma,\
                           male_productivity, female_productivity, parental_leave,\
                          round_length, num_rounds)

basic_sim.run_simulation(prnt=True)
# Out:
# Pre-Simulation Demographic Info:
#
# Overall Gender Distribution:
#
# population male: 513, population female: 487, total: 1000
#
# Level-Split Gender Distribution:
#
# Population Demographics for level J of size 700:
# population pct. male: 0.505714, population pct. female: 0.494286
#
# Population Demographics for level M of size 200:
# population pct. male: 0.515000, population pct. female: 0.485000
#
# Population Demographics for level S of size 75:
# population pct. male: 0.586667, population pct. female: 0.413333
#
# Population Demographics for level E of size 25:
# population pct. male: 0.480000, population pct. female: 0.520000
#
# Startng Simulation: 40 rounds of 1 seconds each.
# starting new round
# round 1 22% complete
# round 1 43% complete
# round 1 82% complete
# round 1 100% complete
# round complete.
# population male: 521, population female: 479, total: 1000
#
# starting new round
# round 2 22% complete
# round 2 44% complete
# round 2 61% complete
# round 2 83% complete
# round 2 100% complete
# round complete.
# population male: 540, population female: 460, total: 1000
#
# starting new round
# round 3 22% complete
# round 3 44% complete
# round 3 82% complete
# round 3 100% complete
# round complete.
# population male: 538, population female: 462, total: 1000
#
# starting new round
# round 4 22% complete
# round 4 62% complete
# round 4 100% complete
# round complete.
# population male: 542, population female: 458, total: 1000
#
# starting new round
# round 5 22% complete
# round 5 44% complete
# round 5 61% complete
# round 5 83% complete
# female:  0.10581068739807736 11.317257603623883
# male:  0.10421686764281414 11.1654822472387
# female:  0.10266254606245384 11.015215886798543
# female:  0.10160111394925564 10.911287300869237
# male:  0.09971590917653357 10.723994656497148
# male:  0.09893278907191642 10.645149522505086
# male:  0.09783778147228137 10.533850469985552
# female:  0.09662625054418505 10.409246800015424
# male:  0.09631359749663478 10.37683739113563
# female:  0.09628245718584774 10.373603647733178
# round complete.
# population male: 551, population female: 449, total: 1000
#
# starting new round
# round 6 22% complete
# round 6 62% complete
# round 6 84% complete
# round 6 100% complete
# round complete.
# population male: 551, population female: 449, total: 1000
#
# starting new round
# round 7 22% complete
# round 7 44% complete
# round 7 60% complete
# round 7 83% complete
# round 7 100% complete
# round complete.
# population male: 572, population female: 428, total: 1000
#
# starting new round
# round 8 23% complete
# round 8 45% complete
# round 8 61% complete
# round 8 84% complete
# round 8 100% complete
# round complete.
# population male: 574, population female: 426, total: 1000
#
# starting new round
# round 9 22% complete
# round 9 44% complete
# round 9 60% complete
# round 9 83% complete
# round 9 100% complete
# round complete.
# population male: 561, population female: 439, total: 1000
#
# starting new round
# round 10 22% complete
# round 10 44% complete
# round 10 65% complete
# round 10 82% complete
# male:  0.11223020035381531 12.420825863283355
# female:  0.10777248072103475 12.015528090987111
# female:  0.10050377573218812 11.317257603623883
# male:  0.09993119377166054 11.26012350975669
# male:  0.09898989365487144 11.1654822472387
# female:  0.0988840090587263 11.154780016696972
# female:  0.09885860841432631 11.152210955473418
# female:  0.09751352873021574 11.015215886798543
# male:  0.09293074914286652 10.533850469985552
# male:  0.09238556042029494 10.475011580226516
# round 10 100% complete
# round complete.
# population male: 573, population female: 427, total: 1000
#
# starting new round
# round 11 22% complete
# round 11 44% complete
# round 11 61% complete
# round 11 82% complete
# round 11 100% complete
# round complete.
# population male: 570, population female: 430, total: 1000
#
# starting new round
# round 12 22% complete
# round 12 44% complete
# male:  0.11541653996712796 12.420825863283355
# female:  0.10335718917075795 11.317257603623883
# male:  0.10276835097459197 11.26012350975669
# female:  0.10169143552855062 11.154780016696972
# female:  0.10166531373174066 11.152210955473418
# female:  0.09604384010980793 10.58339670290561
# male:  0.09556915597414034 10.533850469985552
# male:  0.09500848874027694 10.475011580226516
# female:  0.0943993716025632 10.410693316300257
# male:  0.0940803142004425 10.37683739113563
# round 12 60% complete
# round 12 82% complete
# round 12 100% complete
# round complete.
# population male: 563, population female: 437, total: 1000
#
# starting new round
# round 13 21% complete
# round 13 44% complete
# round 13 60% complete
# round 13 82% complete
# round 13 100% complete
# round complete.
# population male: 568, population female: 432, total: 1000
#
# starting new round
# round 14 22% complete
# round 14 43% complete
# round 14 65% complete
# round 14 81% complete
# round 14 100% complete
# round complete.
# population male: 577, population female: 423, total: 1000
#
# starting new round
# round 15 22% complete
# round 15 44% complete
# round 15 61% complete
# round 15 82% complete
# round 15 100% complete
# round complete.
# population male: 582, population female: 418, total: 1000
#
# starting new round
# round 16 22% complete
# round 16 44% complete
# round 16 61% complete
# round 16 83% complete
# round 16 100% complete
# round complete.
# population male: 580, population female: 420, total: 1000
#
# starting new round
# round 17 23% complete
# round 17 45% complete
# round 17 61% complete
# round 17 82% complete
# female:  0.13117673977688638 13.996686254809827
# female:  0.1003438419247763 11.317257603623883
# female:  0.09978177738051819 11.261086282423566
# female:  0.09876401283369027 11.158563488017446
# female:  0.09697267623313961 10.975523034779748
# female:  0.09659166349739341 10.93615491270003
# male:  0.09610294905480805 10.885430558346687
# female:  0.09413694753758385 10.678736637093483
# female:  0.09324371131944147 10.58339670290561
# male:  0.09288568044176247 10.544925474275558
# round 17 100% complete
# round complete.
# population male: 573, population female: 427, total: 1000
#
# starting new round
# round 18 22% complete
# round 18 44% complete
# round 18 82% complete
# round 18 100% complete
# round complete.
# population male: 573, population female: 427, total: 1000
#
# starting new round
# round 19 22% complete
# female:  0.10719239987872584 11.317257603623883
# female:  0.10659197392103792 11.261086282423566
# female:  0.10359114908003447 10.975523034779748
# female:  0.10056187933661102 10.678736637093483
# female:  0.09960767893881224 10.58339670290561
# female:  0.09797678075346285 10.418309304035038
# male:  0.09710479524536837 10.328911695778448
# male:  0.0965488865314178 10.271498871415616
# male:  0.09545778585392121 10.157845277107402
# female:  0.0953666704606082 10.148295620632837
# round 19 44% complete
# round 19 61% complete
# round 19 84% complete
# round 19 100% complete
# round complete.
# population male: 576, population female: 424, total: 1000
#
# starting new round
# round 20 22% complete
# round 20 44% complete
# round 20 61% complete
# round 20 83% complete
# round 20 100% complete
# round complete.
# population male: 567, population female: 433, total: 1000
#
# starting new round
# round 21 22% complete
# round 21 44% complete
# round 21 61% complete
# female:  0.1058545179529193 11.32237763401354
# female:  0.10580033399039955 11.317257603623883
# male:  0.10555118631399299 11.2936809772096
# female:  0.1022458512312132 10.975523034779748
# male:  0.10145424293962624 10.897799724946651
# female:  0.10121454982973638 10.874146036742278
# male:  0.09529504379957925 10.271498871415616
# female:  0.09423798041374594 10.159953735631166
# male:  0.09421811282101272 10.157845277107402
# female:  0.09412818070777439 10.148295620632837
# round 21 83% complete
# round 21 100% complete
# round complete.
# population male: 580, population female: 420, total: 1000
#
# starting new round
# round 22 22% complete
# round 22 45% complete
# round 22 62% complete
# round 22 84% complete
# round 22 100% complete
# round complete.
# population male: 580, population female: 420, total: 1000
#
# starting new round
# round 23 21% complete
# round 23 44% complete
# round 23 60% complete
# round 23 82% complete
# round 23 100% complete
# round complete.
# population male: 586, population female: 414, total: 1000
#
# starting new round
# round 24 22% complete
# round 24 44% complete
# round 24 61% complete
# round 24 83% complete
# round 24 100% complete
# round complete.
# population male: 594, population female: 406, total: 1000
#
# starting new round
# round 25 22% complete
# round 25 44% complete
# round 25 60% complete
# round 25 83% complete
# round 25 100% complete
# round complete.
# population male: 595, population female: 405, total: 1000
#
# starting new round
# round 26 21% complete
# round 26 43% complete
# round 26 82% complete
# round 26 100% complete
# round complete.
# population male: 610, population female: 390, total: 1000
#
# starting new round
# round 27 22% complete
# round 27 44% complete
# round 27 60% complete
# round 27 83% complete
# round 27 100% complete
# round complete.
# population male: 606, population female: 394, total: 1000
#
# starting new round
# round 28 22% complete
# round 28 44% complete
# round 28 61% complete
# round 28 83% complete
# round complete.
# population male: 597, population female: 403, total: 1000
#
# starting new round
# round 29 22% complete
# round 29 44% complete
# round 29 82% complete
# round 29 100% complete
# round complete.
# population male: 592, population female: 408, total: 1000
#
# starting new round
# round 30 22% complete
# round 30 44% complete
# round 30 61% complete
# round 30 83% complete
# round complete.
# population male: 599, population female: 401, total: 1000
#
# starting new round
# round 31 23% complete
# round 31 45% complete
# round 31 62% complete
# round 31 84% complete
# round 31 100% complete
# round complete.
# population male: 586, population female: 414, total: 1000
#
# starting new round
# round 32 22% complete
# round 32 44% complete
# round 32 60% complete
# round 32 82% complete
# round 32 100% complete
# round complete.
# population male: 584, population female: 416, total: 1000
#
# starting new round
# round 33 22% complete
# round 33 45% complete
# round 33 61% complete
# round 33 83% complete
# round complete.
# population male: 591, population female: 409, total: 1000
#
# starting new round
# round 34 22% complete
# round 34 44% complete
# round 34 60% complete
# round 34 82% complete
# round 34 100% complete
# round complete.
# population male: 591, population female: 409, total: 1000
#
# starting new round
# round 35 23% complete
# round 35 45% complete
# round 35 62% complete
# round 35 84% complete
# round 35 100% complete
# round complete.
# population male: 584, population female: 416, total: 1000
#
# starting new round
# round 36 21% complete
# round 36 43% complete
# round 36 60% complete
# round 36 82% complete
# round 36 100% complete
# round complete.
# population male: 592, population female: 408, total: 1000
#
# starting new round
# round 37 22% complete
# round 37 44% complete
# round 37 60% complete
# round 37 82% complete
# round 37 100% complete
# round complete.
# population male: 593, population female: 407, total: 1000
#
# starting new round
# round 38 22% complete
# round 38 44% complete
# round 38 60% complete
# round 38 82% complete
# round 38 100% complete
# round complete.
# population male: 605, population female: 395, total: 1000
#
# starting new round
# round 39 22% complete
# round 39 45% complete
# round 39 61% complete
# round 39 83% complete
# round complete.
# population male: 605, population female: 395, total: 1000
#
# starting new round
# round 40 22% complete
# round 40 44% complete
# round 40 61% complete
# round 40 83% complete
# round 40 100% complete
# round complete.
# population male: 606, population female: 394, total: 1000
#
# Simulation Complete. Final Stats:
#
# Population Demographics for level J of size 700:
# population pct. male: 0.621429, population pct. female: 0.378571
#
# Population Demographics for level M of size 200:
# population pct. male: 0.570000, population pct. female: 0.430000
#
# Population Demographics for level S of size 75:
# population pct. male: 0.613333, population pct. female: 0.386667
#
# Population Demographics for level E of size 25:
# population pct. male: 0.440000, population pct. female: 0.560000

# %%
def create_simulation_data(n, sim_type, parental_leave, round_length, num_rounds):
    stats = np.zeros((6,n))

    for i in range(n):
        sim = Simulation(sim_type,level_sizes,\
                         sim_types[sim_type][0],sim_types[sim_type][1],sim_types[sim_type][2],\
                         parental_leave,\
                         round_length, num_rounds)
        
        alpha = max(np.random.normal(2,4),0)
        gamma = max(np.random.normal(5,4),0)
        
        stats[0, i] = 100
        stats[1, i] = 200
        
        sim.run_simulation(alpha, gamma)
        
        num_men = sim.get_final_gender_distributions()

        for j in range(len(num_men)):
            stats[j+2,i] = num_men[j]
            
        print("Simulation %i finished. %i Percent complete." % (i+1, round(100*(i+1)/n)))
    
    
    
    ts = make_timestamp()
    
    folder_path = os.path.join(path, "%s_%s_data" % (ts, sim_type))
    
    try:   
        folder = os.mkdir(folder_path)
    except:
        raise Exception("Timestamp didn't work for some reason. Please retry")
    
    listing = ts + "_" + sim_type + "_rawdata.csv"
    print(listing)
    
    save_path = os.path.join(folder_path, listing)
                                   
    np.savetxt(save_path, stats, delimiter=",")
    
    means = np.zeros(4)
    hws = np.zeros(4)
    
    rel_stats = stats[2:]
    
    for i in range(4):
        means[i], hws[i] = (rel_stats[i].mean(), rel_stats[i].std())

    for i in range(1,5):
        hws[i-1] = 1.96*hws[i-1]/math.sqrt(n)
        print("95 Perc. CI for number of men for level %s: %f +- %f" % (work_levels[i], means[i-1], hws[i-1]))

    plt.figure()
    plt.bar([work_levels[i+1] for i in range(4)], means, yerr=hws)
    plt.show()

# %%
# create_simulation_data(n, "base", round_length, num_rounds)
