# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import time
import random

import worker as wr
import simulation as sm

import os

# %% [markdown]
# # Simulation Project Demo (FA23)
#
# The purpose of this notebook is to further modularize simulation model v1 and incorporate our own twists to examine the behavior of gender-based bias in the corporate workplace.

# %%
# Global Variables / References:

# Appropriate staff sizes for each level:
level_sizes = {
    1 : 800,
    2 : 175,
    3 : 50,
    4 : 15
}

# The impact that seniority has on staying time - older people retire later?
# Set negative for opposite effect.
level_ext_stay_times = {
    1 : 1,
    2 : 2,
    3 : 3,
    4 : 1.5
}

# The impact that gender has on staying time -- women pushed out quicker?
gender_stay_times = {
    0 : 4.3,
    1 : 2.15
}

# A database to store workers, organized by level:
# Implemented as simple lists, ordered from most to least senior by employee index.
worker_db = {
    1 : [],
    2 : [],
    3 : [],
    4 : []
}

# %% [markdown]
# ### Base Hiring/Promoting/Leaving Processes

# %%
def base_remove_expired_workers(worker_db):
    """
    This function traverses through the database of workers, and removes
    those with end times that have been reached. It does so by iterating through
    each level of worker in the database, checking the current time vs. the
    worker's end time. If this time has passed, then we remove the worker.
    """
    for level in worker_db.keys():
        
        l = len(worker_db[level])
        idx = 0
        
#       keys are being changed during the loop- for loop won't work!
        while idx < l:
#           if a worker has 'expired', kick 'em out!
            if worker_db[level][idx].get_end_time() < time.time():
                worker_db[level] = worker_db[level][:idx] \
                                    + worker_db[level][idx+1:]
#               reflect that the size of the level is one less after removal
                l -= 1
            idx += 1
            
    
def base_check_leave(worker_db, leave_db):
    for level in worker_db.keys():
        l = len(worker_db[level])
        idx = 0
        
        while idx < l:
            if worker_db[level][idx].det_go_on_leave():
                leave_db[level].append(worker_db[level][idx])
                worker_db[level] = worker_db[level][:idx] \
                                        + worker_db[level][idx+1:]
                l -= 1
            idx += 1
     
    for level in leave_db.keys():
        l = len(leave_db[level])
        idx = 0
        
        while idx < l:
            if time.time() > leave_db[level][idx].get_leave_time():
                worker_db[level].append(leave_db[level][idx])
                worker_db[level][len(worker_db[level]) - 1].set_end_time(gender_stay_times, level_ext_stay_times)
                leave_db[level] = leave_db[level][:idx] + leave_db[level][idx+1:]
                l -= 1
            idx += 1      

def base_hire_worker(worker_db, level, idx, male_productivity=(5,2), female_productivity=(5,2),\
                     all_male=False, all_female=False):
    """
    This function hires new workers
    """
    
    assert not all_female or not all_male
    # Randomized gender for new hire -- Change to 3 evenutally for NB case?
    if all_female:
        gender = 1
    elif all_male:
        gender = 0
    else:
        gender = random.randint(0,1)

    # Create worker:
    hire = wr.Worker(level, gender, idx, time.time())
    hire.set_end_time(gender_stay_times, level_ext_stay_times)
    hire.set_productivity(male_productivity, female_productivity)
    

    # Add worker to worker database:     
    worker_db[hire.get_level()].append(hire)
    
    
def base_promote_workers(worker_db, leave_db, alpha, gamma, pt=False, n=1):
    # Promote to fill ranks:           
    level = max(worker_db.keys())
#     print(level)
#   Promote employees to fill levels 2-4. Work from top to ensure each level is full.
    while level > 1:
        while (len(worker_db[level]) + len(leave_db[level])) < level_sizes[level]:
#           promote most senior employee from one level down:
            worker_db[level].append(worker_db[level-1][0])
    
            if pt:
                print("level size: ", level_sizes[level], "promotion made at level: ", level)
            
#           adjust level, end time for promoted employee
            worker_db[level][len(worker_db[level]) - 1].promote(gender_stay_times, level_ext_stay_times)
            worker_db[level][len(worker_db[level]) - 1].set_end_time(gender_stay_times, level_ext_stay_times)
        
#           remove employee from level below
            worker_db[level-1] = worker_db[level-1][1:]
        level -= 1

# %% [markdown]
# ### Alternative Hiring/Promoting/Leaving Processes

# %%
def logit_promote_workers(worker_db, leave_db, alpha, gamma, pt=False, n=5):
    level = max(worker_db.keys())
    
    while level > 1:
        while len(worker_db[level]) + len(leave_db[level]) < level_sizes[level]:
            
            worker_pool = worker_db[level-1][:n]
            
            probabilities = [math.e**((gamma*worker.get_time_on_level() \
                                      + alpha*int(worker.is_male()))) \
                                         for worker in worker_pool]
            
            ps = [p / sum(probabilities) for p in probabilities]
            
            cumul_probabilities = [sum(ps[:i+1]) for i in range(len(ps))]
            
            u = np.random.uniform()
            
            for i in range(len(cumul_probabilities)):
                if cumul_probabilities[i] >= u:
                    selection = i
                    break
                    
            
            worker_db[level].append(worker_db[level-1][selection])
            
            worker_db[level][len(worker_db[level]) - 1].promote(gender_stay_times, level_ext_stay_times)
            worker_db[level][len(worker_db[level]) - 1].set_end_time(gender_stay_times, level_ext_stay_times),
            
            worker_db[level-1] = worker_db[level-1][:selection] \
                                    + worker_db[level-1][selection+1:]
        level -= 1
        
            
def prod_promote_workers(worker_db, leave_db, alpha, gamma, pt=False, n=5):
    """
    Promote workers based off their productivity. 
    
    Modeled mathematically as INSERT MODEL HERE
    
    Inputs: 
    - worker_db: the database of workers
    - n: number of workers selected to promote from
    - alpha, gamma: currently unused sensitivity tuning params
    
    Outputs:
    - None
    """
    # @TODO
    level = max(worker_db.keys())
    
    while level > 1:
        while (len(worker_db[level]) + len(leave_db[level])) < level_sizes[level]:
            
            worker_pool = worker_db[level-1][:n]
            
            probabilities = [math.e**((worker.get_productivity())) \
                                         for worker in worker_pool]
                    
            ps = [p / sum(probabilities) for p in probabilities]
            
            
            cumul_probabilities = [sum(ps[:i+1]) for i in range(len(ps))]
            
            u = np.random.uniform()
            
            for i in range(len(cumul_probabilities)):
                if cumul_probabilities[i] >= u:
                    selection = i
                    break
            
            if pt:
                print("level size: ", len(worker_db[level]), "hire made at level: ", level)
            worker_db[level].append(worker_db[level-1][selection])
            
            worker_db[level][len(worker_db[level]) - 1].promote(gender_stay_times, level_ext_stay_times)
            worker_db[level][len(worker_db[level]) - 1].set_end_time(gender_stay_times, level_ext_stay_times)
            
            worker_db[level-1] = worker_db[level-1][:selection] \
                                    + worker_db[level-1][selection+1:]
        level -= 1

# %% [markdown]
# ## Testing / Playground:

# %%
def make_timestamp():
    t = time.time()
    t = str(t).split(".")[1]
    t = t[0:len(t)-2]
    return t

# %% [markdown]
# ## Simulations:
#
# To run a simulation, call an object and pass in the worker database, level sizes, hiring/promoting/leaving processes, and round length.

# %%
n=3
round_length = 1
num_rounds = 45

parental_leave = False

# Alpha / Gamma Values - Used in Logit/Prod Analysis
alpha = -6
gamma = 1

male_productivity = (6,2)
female_productivity = (6,2)

sim_type = "logit"

path = os.path.join(os.getcwd(), "simulation_data")

# %%
sim_types = {
    
    "base" : (base_remove_expired_workers, \
              base_hire_worker, base_promote_workers),
    
    "logit" : (base_remove_expired_workers, \
              base_hire_worker, logit_promote_workers),
    
    "prod" : (base_remove_expired_workers, \
              base_hire_worker, prod_promote_workers, \
             male_productivity, female_productivity)
}

# %%
basic_sim = sm.Simulation(sim_type, level_sizes, \
                          sim_types[sim_type][0],sim_types[sim_type][1],sim_types[sim_type][2], \
                          alpha, gamma,\
                           male_productivity, female_productivity, parental_leave,\
                          round_length, num_rounds)

basic_sim.run_simulation(prnt=True)
# Out:
# Pre-Simulation Demographic Info:
#
# Overall Gender Distribution:
#
# population male: 506, population female: 534, total: 1040
#
# Level-Split Gender Distribution:
#
# Population Demographics for level J of size 800:
# population pct. male: 0.495000, population pct. female: 0.505000
#
# Population Demographics for level M of size 175:
# population pct. male: 0.440000, population pct. female: 0.560000
#
# Population Demographics for level S of size 50:
# population pct. male: 0.500000, population pct. female: 0.500000
#
# Population Demographics for level E of size 15:
# population pct. male: 0.533333, population pct. female: 0.466667
#
# Startng Simulation: 45 rounds of 1 seconds each.
# starting new round
# round 1 6% complete
# round 1 23% complete
# round 1 40% complete
# round 1 63% complete
# round 1 80% complete
# round 1 100% complete
# round complete.
# population male: 547, population female: 493, total: 1040
#
# starting new round
# round 2 6% complete
# round 2 23% complete
# round 2 41% complete
# round 2 64% complete
# round 2 81% complete
# round 2 100% complete
# round complete.
# population male: 562, population female: 478, total: 1040
#
# starting new round
# round 3 5% complete
# round 3 24% complete
# round 3 40% complete
# round 3 46% complete
# round 3 63% complete
# round 3 81% complete
# round 3 100% complete
# round complete.
# population male: 585, population female: 455, total: 1040
#
# starting new round
# round 4 24% complete
# round 4 42% complete
# round 4 65% complete
# round 4 83% complete
# round 4 100% complete
# round complete.
# population male: 604, population female: 436, total: 1040
#
# starting new round
# round 5 6% complete
# round 5 24% complete
# round 5 42% complete
# round 5 66% complete
# round 5 84% complete
# round 5 100% complete
# round complete.
# population male: 617, population female: 423, total: 1040
#
# starting new round
# round 6 6% complete
# round 6 23% complete
# round 6 41% complete
# round 6 64% complete
# round 6 82% complete
# round 6 100% complete
# round complete.
# population male: 606, population female: 434, total: 1040
#
# starting new round
# round 7 6% complete
# round 7 23% complete
# round 7 41% complete
# round 7 84% complete
# round 7 100% complete
# round complete.
# population male: 620, population female: 420, total: 1040
#
# starting new round
# round 8 6% complete
# round 8 22% complete
# round 8 46% complete
# round 8 64% complete
# round 8 82% complete
# round 8 100% complete
# round complete.
# population male: 645, population female: 395, total: 1040
#
# starting new round
# round 9 6% complete
# round 9 23% complete
# round 9 41% complete
# round 9 64% complete
# round 9 82% complete
# round 9 100% complete
# round complete.
# population male: 647, population female: 393, total: 1040
#
# starting new round
# round 10 6% complete
# round 10 23% complete
# round 10 41% complete
# round 10 64% complete
# round 10 82% complete
# round 10 100% complete
# round complete.
# population male: 649, population female: 391, total: 1040
#
# starting new round
# round 11 6% complete
# round 11 23% complete
# round 11 41% complete
# round 11 65% complete
# round 11 82% complete
# round 11 100% complete
# round complete.
# population male: 652, population female: 388, total: 1040
#
# starting new round
# round 12 6% complete
# round 12 24% complete
# round 12 41% complete
# round 12 65% complete
# round 12 83% complete
# round 12 100% complete
# round complete.
# population male: 651, population female: 389, total: 1040
#
# starting new round
# round 13 6% complete
# round 13 23% complete
# round 13 41% complete
# round 13 65% complete
# round 13 83% complete
# round 13 100% complete
# round complete.
# population male: 671, population female: 369, total: 1040
#
# starting new round
# round 14 6% complete
# round 14 24% complete
# round 14 42% complete
# round 14 65% complete
# round 14 83% complete
# round 14 100% complete
# round complete.
# population male: 668, population female: 372, total: 1040
#
# starting new round
# round 15 6% complete
# round 15 23% complete
# round 15 41% complete
# round 15 65% complete
# round 15 83% complete
# round 15 100% complete
# round complete.
# population male: 662, population female: 378, total: 1040
#
# starting new round
# round 16 24% complete
# round 16 42% complete
# round 16 65% complete
# round 16 83% complete
# round 16 100% complete
# round complete.
# population male: 665, population female: 375, total: 1040
#
# starting new round
# round 17 6% complete
# round 17 24% complete
# round 17 41% complete
# round 17 66% complete
# round 17 83% complete
# round 17 100% complete
# round complete.
# population male: 666, population female: 374, total: 1040
#
# starting new round
# round 18 6% complete
# round 18 24% complete
# round 18 42% complete
# round 18 66% complete
# round 18 84% complete
# round 18 100% complete
# round complete.
# population male: 675, population female: 365, total: 1040
#
# starting new round
# round 19 24% complete
# round 19 42% complete
# round 19 60% complete
# round 19 84% complete
# round 19 100% complete
# round complete.
# population male: 671, population female: 369, total: 1040
#
# starting new round
# round 20 6% complete
# round 20 24% complete
# round 20 42% complete
# round 20 64% complete
# round 20 82% complete
# round 20 100% complete
# round complete.
# population male: 675, population female: 365, total: 1040
#
# starting new round
# round 21 6% complete
# round 21 23% complete
# round 21 40% complete
# round 21 64% complete
# round 21 82% complete
# round 21 100% complete
# round complete.
# population male: 680, population female: 360, total: 1040
#
# starting new round
# round 22 23% complete
# round 22 41% complete
# round 22 65% complete
# round 22 83% complete
# round 22 100% complete
# round complete.
# population male: 674, population female: 366, total: 1040
#
# starting new round
# round 23 6% complete
# round 23 23% complete
# round 23 41% complete
# round 23 64% complete
# round 23 81% complete
# round 23 100% complete
# round complete.
# population male: 675, population female: 365, total: 1040
#
# starting new round
# round 24 6% complete
# round 24 24% complete
# round 24 42% complete
# round 24 60% complete
# round 24 84% complete
# round 24 100% complete
# round complete.
# population male: 662, population female: 378, total: 1040
#
# starting new round
# round 25 24% complete
# round 25 42% complete
# round 25 61% complete
# round 25 84% complete
# round 25 100% complete
# round complete.
# population male: 665, population female: 375, total: 1040
#
# starting new round
# round 26 24% complete
# round 26 41% complete
# round 26 64% complete
# round 26 82% complete
# round 26 100% complete
# round complete.
# population male: 654, population female: 386, total: 1040
#
# starting new round
# round 27 6% complete
# round 27 24% complete
# round 27 41% complete
# round 27 65% complete
# round 27 82% complete
# round 27 100% complete
# round complete.
# population male: 640, population female: 400, total: 1040
#
# starting new round
# round 28 6% complete
# round 28 23% complete
# round 28 41% complete
# round 28 65% complete
# round 28 83% complete
# round 28 100% complete
# round complete.
# population male: 644, population female: 396, total: 1040
#
# starting new round
# round 29 24% complete
# round 29 42% complete
# round 29 60% complete
# round 29 83% complete
# round 29 100% complete
# round complete.
# population male: 656, population female: 384, total: 1040
#
# starting new round
# round 30 24% complete
# round 30 42% complete
# round 30 66% complete
# round 30 84% complete
# round 30 100% complete
# round complete.
# population male: 657, population female: 383, total: 1040
#
# starting new round
# round 31 6% complete
# round 31 24% complete
# round 31 41% complete
# round 31 64% complete
# round 31 82% complete
# round 31 100% complete
# round complete.
# population male: 660, population female: 380, total: 1040
#
# starting new round
# round 32 6% complete
# round 32 24% complete
# round 32 42% complete
# round 32 66% complete
# round 32 84% complete
# round 32 100% complete
# round complete.
# population male: 664, population female: 376, total: 1040
#
# starting new round
# round 33 6% complete
# round 33 24% complete
# round 33 41% complete
# round 33 65% complete
# round 33 83% complete
# round 33 100% complete
# round complete.
# population male: 669, population female: 371, total: 1040
#
# starting new round
# round 34 24% complete
# round 34 41% complete
# round 34 65% complete
# round 34 82% complete
# round 34 100% complete
# round complete.
# population male: 671, population female: 369, total: 1040
#
# starting new round
# round 35 6% complete
# round 35 24% complete
# round 35 41% complete
# round 35 65% complete
# round 35 82% complete
# round 35 100% complete
# round complete.
# population male: 668, population female: 372, total: 1040
#
# starting new round
# round 36 6% complete
# round 36 24% complete
# round 36 42% complete
# round 36 66% complete
# round 36 83% complete
# round 36 100% complete
# round complete.
# population male: 663, population female: 377, total: 1040
#
# starting new round
# round 37 24% complete
# round 37 42% complete
# round 37 66% complete
# round 37 83% complete
# round 37 100% complete
# round complete.
# population male: 648, population female: 392, total: 1040
#
# starting new round
# round 38 24% complete
# round 38 42% complete
# round 38 65% complete
# round 38 83% complete
# round 38 100% complete
# round complete.
# population male: 632, population female: 408, total: 1040
#
# starting new round
# round 39 6% complete
# round 39 23% complete
# round 39 40% complete
# round 39 64% complete
# round 39 82% complete
# round 39 100% complete
# round complete.
# population male: 634, population female: 406, total: 1040
#
# starting new round
# round 40 24% complete
# round 40 41% complete
# round 40 65% complete
# round 40 83% complete
# round 40 100% complete
# round complete.
# population male: 638, population female: 402, total: 1040
#
# starting new round
# round 41 6% complete
# round 41 24% complete
# round 41 42% complete
# round 41 66% complete
# round 41 84% complete
# round 41 100% complete
# round complete.
# population male: 637, population female: 403, total: 1040
#
# starting new round
# round 42 24% complete
# round 42 42% complete
# round 42 65% complete
# round 42 83% complete
# round 42 100% complete
# round complete.
# population male: 668, population female: 372, total: 1040
#
# starting new round
# round 43 6% complete
# round 43 23% complete
# round 43 41% complete
# round 43 64% complete
# round 43 82% complete
# round 43 100% complete
# round complete.
# population male: 663, population female: 377, total: 1040
#
# starting new round
# round 44 24% complete
# round 44 42% complete
# round 44 65% complete
# round 44 84% complete
# round 44 100% complete
# round complete.
# population male: 661, population female: 379, total: 1040
#
# starting new round
# round 45 6% complete
# round 45 23% complete
# round 45 40% complete
# round 45 64% complete
# round 45 82% complete
# round 45 100% complete
# round complete.
# population male: 657, population female: 383, total: 1040
#
# Simulation Complete. Final Stats:
#
# Population Demographics for level J of size 800:
# population pct. male: 0.592500, population pct. female: 0.407500
#
# Population Demographics for level M of size 175:
# population pct. male: 0.720000, population pct. female: 0.280000
#
# Population Demographics for level S of size 50:
# population pct. male: 0.840000, population pct. female: 0.160000
#
# Population Demographics for level E of size 15:
# population pct. male: 1.000000, population pct. female: 0.000000

# %%
def create_simulation_data(n, sim_type, parental_leave, round_length, num_rounds):
    stats = np.zeros((6,n))

    for i in range(n):
        
        alpha = np.random.normal(0,1)
        gamma = np.random.uniform(0,15)
        
        sim = sm.Simulation(sim_type, level_sizes, \
                          sim_types[sim_type][0],sim_types[sim_type][1],sim_types[sim_type][2], \
                          alpha, gamma,\
                           male_productivity, female_productivity, parental_leave,\
                          round_length, num_rounds)
        
        stats[0, i] = alpha
        stats[1, i] = gamma
        
        sim.run_simulation()
        
        num_men = sim.get_steady_state_gender_dist()[1:]

        for j in range(len(num_men)):
            stats[j+2,i] = num_men[j]
            
        print("Simulation %i finished. %i Percent complete." % (i+1, round(100*(i+1)/n)))
    
    
    
    ts = make_timestamp()
    
    folder_path = os.path.join(path, "%s_%s_data" % (ts, sim_type))
    
    try:   
        folder = os.mkdir(folder_path)
    except:
        raise Exception("Timestamp didn't work for some reason. Please retry")
    
    listing = ts + "_" + sim_type + "_rawdata.csv"
    print(listing)
    
    save_path = os.path.join(folder_path, listing)
                                   
    np.savetxt(save_path, stats, delimiter=",")
    
    #means = np.zeros(4)
    #hws = np.zeros(4)
    
    #rel_stats = stats[2:]
    
    #for i in range(4):
    #    means[i], hws[i] = (rel_stats[i].mean(), rel_stats[i].std())

    #for i in range(1,5):
    #    hws[i-1] = 1.96*hws[i-1]/math.sqrt(n)
    #    print("95 Perc. CI for number of men for level %s: %f +- %f" % (work_levels[i], means[i-1], hws[i-1]))

    #plt.figure()
    #plt.bar([work_levels[i+1] for i in range(4)], means, yerr=hws)
    #plt.show()

# %%
create_simulation_data(n, sim_type, False, round_length, num_rounds)
# Out:
# Simulation 1 finished. 33 Percent complete.
# Simulation 2 finished. 67 Percent complete.
# Simulation 3 finished. 100 Percent complete.
# 0269_logit_rawdata.csv
